# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")  # or yolov8s.pt

# %%
""" model.train(data="object_detection_Dataset/data.yaml", epochs=50, imgsz=640) """

# %%
model = YOLO(r"C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix\project_4\yolo\train2\weights\best.pt")   # path to your best.pt

# %%
results = model.predict(
    r"C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix\project_4\yolo\object_detection_Dataset\test\images",
    save=True,
    project=r"C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix\project_4\yolo",  # folder where you want results
    name="predictions"                             # subfolder name
)
# Out:
# image 1/224 C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix\project_4\yolo\object_detection_Dataset\test\images\00083b384685315d_jpg.rf.abfd1b2cc8c681777bae66d5327bb9ea.jpg: 640x640 1 Bird, 106.2ms
# image 2/224 C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix\project_4\yolo\object_detection_Dataset\test\images\00188d7f40a84793_jpg.rf.7f9da2b662dc236fbdcc1f22d8e0983e.jpg: 640x640 1 Bird, 88.3ms
# image 3/224 C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix\project_4\yolo\object_detection_Dataset\test\images\0028adf0e92c3da2_jpg.rf.48c97d30547a46e83abcbd1bf801c72f.jpg: 640x640 1 Bird, 89.0ms
# image 4/224 C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix\project_4\yolo\object_detection_Dataset\test\images\00347cbbeed4bedb_jpg.rf.aa19c9a7a22d76f8539ca12ac7cb82d5.jpg: 640x640 1 Bird, 86.3ms
# ...

# %%
results = model.predict(
    r"C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix\project_4\yolo\extra_test_images\extra_test_images1.jpg",
    save=True,
    project=r"C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix\project_4\yolo\predictions3",  # folder where you want results
)
# Out:
# image 1/1 C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix\project_4\yolo\extra_test_images\extra_test_images1.jpg: 384x640 8 Birds, 1 drone, 89.4ms
# Speed: 3.7ms preprocess, 89.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix\project_4\yolo\predictions3\predictions

# %%
# to find the corrupted .pt files if downloading model gets interepted

""" import os

root = r"C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix"   # <-- put your correct project_4 path here

for current_path, dirs, files in os.walk(root):
    for f in files:
        if f.endswith(".pt"):
            print(os.path.join(current_path, f))
 """
# Out:
# C:\Users\Admin\Desktop\sb\ds_ml\internship\labmentix\project_4\yolo\yolov8n.pt
